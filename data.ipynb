# %% [markdown]
# # Data Generation for the GTZan Music Genre Classification

# %% [markdown]
# ## Import Statements

# %% [markdown]
# Start by importing necessary libraries.

# %%
import os
import librosa
import pandas as pd
from pydub import AudioSegment
import tempfile
import numpy as np
import soundfile as sf

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Convert to MP3 function.

# %%
# Function to convert MP3 to WAV
def convert_mp3_to_wav(mp3_file):
    try:
        sound = AudioSegment.from_mp3(mp3_file)
        wav_file = tempfile.mktemp(suffix='.wav')
        sound.export(wav_file, format="wav")
        return wav_file
    except Exception as e:
        print(f"Error converting {mp3_file} to WAV: {e}")
        return None

# %% [markdown]
# Feature extraction from a segment.

# %%
# Function to extract features from an audio segment
def extract_features_from_segment(y, sr, start_time, end_time):
    segment = y[start_time:end_time]

    chroma_stft = librosa.feature.chroma_stft(y=segment, sr=sr)
    rms = librosa.feature.rms(y=segment)
    spectral_centroid = librosa.feature.spectral_centroid(y=segment, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=segment, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=segment, sr=sr)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y=segment)
    harmony, perceptr = librosa.effects.hpss(segment)
    tempo, _ = librosa.beat.beat_track(y=segment, sr=sr)
    mfcc = librosa.feature.mfcc(y=segment, sr=sr, n_mfcc=20)

    features = {
        'chroma_stft_mean': chroma_stft.mean() if chroma_stft.size else 0,
        'chroma_stft_var': chroma_stft.var() if chroma_stft.size else 0,
        'rms_mean': rms.mean() if rms.size else 0,
        'rms_var': rms.var() if rms.size else 0,
        'spectral_centroid_mean': spectral_centroid.mean() if spectral_centroid.size else 0,
        'spectral_centroid_var': spectral_centroid.var() if spectral_centroid.size else 0,
        'spectral_bandwidth_mean': spectral_bandwidth.mean() if spectral_bandwidth.size else 0,
        'spectral_bandwidth_var': spectral_bandwidth.var() if spectral_bandwidth.size else 0,
        'rolloff_mean': rolloff.mean() if rolloff.size else 0,
        'rolloff_var': rolloff.var() if rolloff.size else 0,
        'zero_crossing_rate_mean': zero_crossing_rate.mean() if zero_crossing_rate.size else 0,
        'zero_crossing_rate_var': zero_crossing_rate.var() if zero_crossing_rate.size else 0,
        'harmony_mean': harmony.mean() if harmony.size else 0,
        'harmony_var': harmony.var() if harmony.size else 0,
        'perceptr_mean': perceptr.mean() if perceptr.size else 0,
        'perceptr_var': perceptr.var() if perceptr.size else 0,
        'tempo': tempo,
    }

    for i in range(1, 21):
        features[f'mfcc{i}_mean'] = mfcc[i-1].mean() if mfcc.shape[0] >= i else 0
        features[f'mfcc{i}_var'] = mfcc[i-1].var() if mfcc.shape[0] >= i else 0

    return features

# %% [markdown]
# Load audio helpfer function.

# %%
# Function to load audio file
def load_audio(file_path):
    try:
        y, sr = librosa.load(file_path, sr=None)
    except sf.LibsndfileError:
        print(f"LibsndfileError: {file_path}")
        return None, None
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None, None
    return y, sr

# %% [markdown]
# Segment data and call feature extraction.

# %%
# Function to extract features from an audio file
def extract_features(audio_file, segment_duration=30):
    try:
        y, sr = load_audio(audio_file)
        if y is None:
            return []

        total_duration = len(y) / sr
        segment_length = int(sr * segment_duration)

        features_list = []

        for start in range(0, len(y), segment_length):
            end = start + segment_length
            if end <= len(y):
                segment_features = extract_features_from_segment(y, sr, start, end)
                all_features = segment_features
                all_features['filename'] = os.path.basename(audio_file)
                all_features['start'] = start / sr
                all_features['end'] = end / sr
                features_list.append(all_features)

        return features_list

    except Exception as e:
        print(f"Error extracting features from {audio_file}: {e}")
        return []

# %% [markdown]
# ## Define Data Paths

# %% [markdown]
# Specify the paths to the CSV files containing data.

# %%
# List of genres
genres = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]

# Base folder containing genre subfolders
base_folder_path = '/Users/isaiah/Desktop/Career/Projects/music-genre-detector/GTZan/genres_original'

# %% [markdown]
# ## Process Input Audio Files

# %% [markdown]
# Process input files and label the data.

# %%
# Function to process a folder of audio files
def process_audio_folder(folder_path, genre_label):
    results = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.wav') or filename.endswith('.mp3'):
            file_path = os.path.join(folder_path, filename)
            if filename.endswith('.mp3'):
                file_path = convert_mp3_to_wav(file_path)
            features_list = extract_features(file_path)
            for features in features_list:
                features['genre'] = genre_label
                results.append(features)
    return results

# %% [markdown]
# ## Create Singular CSV

# %% [markdown]
# Aggregate results of the feature extraction into a singular CSV.

# %%
all_results = []

for genre in genres:
    print(f"Processing genre: {genre}")
    folder_path = os.path.join(base_folder_path, genre)
    genre_results = process_audio_folder(folder_path, genre)
    all_results.extend(genre_results)
    print(f"Completed processing genre: {genre}")

print("Writing results to CSV file...")
df = pd.DataFrame(all_results)
csv_file_path = '/Users/isaiah/Desktop/Career/Projects/music-genre-detector/all_genres_audio_features.csv'
df.to_csv(csv_file_path, index=False)
print("CSV file generation completed.")

df.head()
# Out:
# Processing genre: blues
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 6
#       4 print(f"Processing genre: {genre}")
#       5 folder_path = os.path.join(base_folder_path, genre)
# ----> 6 genre_results = process_audio_folder(folder_path, genre)
#       7 all_results.extend(genre_results)
#       8 print(f"Completed processing genre: {genre}")
#
# Cell In[21], line 9, in process_audio_folder(folder_path, genre_label)
#       7 if filename.endswith('.mp3'):
#       8     file_path = convert_mp3_to_wav(file_path)
# ----> 9 features_list = extract_features(file_path)
#      10 for features in features_list:
#      11     features['genre'] = genre_label
#
# Cell In[19], line 16, in extract_features(audio_file, segment_duration)
#      14 end = start + segment_length
#      15 if end <= len(y):
# ---> 16     segment_features = extract_features_from_segment(y, sr, start, end)
#      17     all_features = segment_features
#      18     all_features['filename'] = os.path.basename(audio_file)
#
# Cell In[17], line 11, in extract_features_from_segment(y, sr, start_time, end_time)
#       9 rolloff = librosa.feature.spectral_rolloff(y=segment, sr=sr)
#      10 zero_crossing_rate = librosa.feature.zero_crossing_rate(y=segment)
# ---> 11 harmony, perceptr = librosa.effects.hpss(segment)
#      12 tempo, _ = librosa.beat.beat_track(y=segment, sr=sr)
#      13 mfcc = librosa.feature.mfcc(y=segment, sr=sr, n_mfcc=20)
#
# File ~/Desktop/Career/Projects/music-genre-detector/.venv/lib/python3.12/site-packages/librosa/effects.py:143, in hpss(y, kernel_size, power, mask, margin, n_fft, hop_length, win_length, window, center, pad_mode)
#     133 stft = core.stft(
#     134     y,
#     135     n_fft=n_fft,
#    (...)
#     139     pad_mode=pad_mode,
#     140 )
#     142 # Decompose into harmonic and percussives
# --> 143 stft_harm, stft_perc = decompose.hpss(
#     144     stft, kernel_size=kernel_size, power=power, mask=mask, margin=margin
#     145 )
#     147 # Invert the STFTs.  Adjust length to match the input.
#     148 y_harm = core.istft(
#     149     stft_harm,
#     150     dtype=y.dtype,
#    (...)
#     155     length=y.shape[-1],
#     156 )
#
# File ~/Desktop/Career/Projects/music-genre-detector/.venv/lib/python3.12/site-packages/librosa/decompose.py:393, in hpss(S, kernel_size, power, mask, margin)
#     390 harm[:] = median_filter(S, size=harm_shape, mode="reflect")
#     392 perc = np.empty_like(S)
# --> 393 perc[:] = median_filter(S, size=perc_shape, mode="reflect")
#     395 split_zeros = margin_harm == 1 and margin_perc == 1
#     397 mask_harm = util.softmask(
#     398     harm, perc * margin_harm, power=power, split_zeros=split_zeros
#     399 )
#
# File ~/Desktop/Career/Projects/music-genre-detector/.venv/lib/python3.12/site-packages/scipy/ndimage/_filters.py:1594, in median_filter(input, size, footprint, output, mode, cval, origin, axes)
#    1547 @_ni_docstrings.docfiller
#    1548 def median_filter(input, size=None, footprint=None, output=None,
#    1549                   mode="reflect", cval=0.0, origin=0, *, axes=None):
#    1550     """
#    1551     Calculate a multidimensional median filter.
#    1552
#    (...)
#    1592     >>> plt.show()
#    1593     """
# -> 1594     return _rank_filter(input, 0, size, footprint, output, mode, cval,
#    1595                         origin, 'median', axes=axes)
#
# File ~/Desktop/Career/Projects/music-genre-detector/.venv/lib/python3.12/site-packages/scipy/ndimage/_filters.py:1495, in _rank_filter(input, rank, size, footprint, output, mode, cval, origin, operation, axes)
#    1491     raise RuntimeError(
#    1492         "A sequence of modes is not supported by non-separable rank "
#    1493         "filters")
#    1494 mode = _ni_support._extend_mode_to_code(mode)
# -> 1495 _nd_image.rank_filter(input, rank, footprint, output, mode, cval,
#    1496                       origins)
#    1497 if temp_needed:
#    1498     temp[...] = output
#
# KeyboardInterrupt:

# %% [markdown]
# ## Examine Data

# %% [markdown]
# Gain insights into data.

# %%
# Get summary statistics
df.describe(include='all')
# Out:
#         chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count        9981.000000      9981.000000  9981.000000  9.981000e+03
# unique               NaN              NaN          NaN           NaN
# top                  NaN              NaN          NaN           NaN
# freq                 NaN              NaN          NaN           NaN
# mean            0.379964         0.084882     0.130039  2.672434e-03
# std             0.090624         0.009675     0.068168  3.561532e-03
# min             0.108073         0.015217     0.000947  4.055916e-08
# 25%             0.316037         0.079820     0.083223  6.285820e-04
# 50%             0.385163         0.085137     0.120488  1.500287e-03
# 75%             0.442906         0.091154     0.175334  3.113760e-03
# max             0.751176         0.120717     0.440458  3.237973e-02
#
#         spectral_centroid_mean  spectral_centroid_var  \
# count              9981.000000           9.981000e+03
# unique                     NaN                    NaN
# top                        NaN                    NaN
# freq                       NaN                    NaN
# mean               2201.910957           4.159255e+05
# std                 750.540439           4.339675e+05
# min                 479.905803           2.161498e+03
# 25%                1634.097152           1.228336e+05
# 50%                2211.777107           2.643931e+05
# 75%                2713.457812           5.612200e+05
# max                5432.278843           4.801847e+06
#
#         spectral_bandwidth_mean  spectral_bandwidth_var  rolloff_mean  \
# count               9981.000000            9.981000e+03   9981.000000
# unique                      NaN                     NaN           NaN
# top                         NaN                     NaN           NaN
# freq                        NaN                     NaN           NaN
# mean                2244.562460            1.183121e+05   4571.568401
# std                  541.420376            1.002501e+05   1639.481644
# min                  499.577102            1.295350e+03    673.906438
# 25%                 1890.204723            4.941410e+04   3389.905912
# 50%                 2233.071916            9.037122e+04   4634.773513
# 75%                 2590.295338            1.578929e+05   5597.307692
# max                 3708.279663            1.237131e+06   9486.121357
#
#          rolloff_var  ...  mfcc18_mean   mfcc18_var  mfcc19_mean   mfcc19_var  \
# count   9.981000e+03  ...  9981.000000  9981.000000  9981.000000  9981.000000
# unique           NaN  ...          NaN          NaN          NaN          NaN
# top              NaN  ...          NaN          NaN          NaN          NaN
# freq             NaN  ...          NaN          NaN          NaN          NaN
# mean    1.623468e+06  ...     0.724376    52.343689    -2.497094    54.811691
# std     1.482634e+06  ...     5.175797    38.067791     5.107192    41.505894
# min     1.130834e+03  ...   -20.749748     3.445752   -27.359076     3.147765
# 25%     5.562385e+05  ...    -2.524088    29.405123    -5.734853    30.384859
# 50%     1.155826e+06  ...     0.730935    41.686157    -2.700388    43.264107
# 75%     2.251497e+06  ...     3.871771    61.854343     0.521315    65.165123
# max     1.293661e+07  ...    36.923038   628.774414    31.367565  1147.502441
#
#         mfcc20_mean   mfcc20_var         filename        start          end  \
# count   9981.000000  9981.000000             9981  9981.000000  9981.000000
# unique          NaN          NaN              999          NaN          NaN
# top             NaN          NaN  blues.00093.wav          NaN          NaN
# freq            NaN          NaN               10          NaN          NaN
# mean      -0.929246    57.142101              NaN    13.487827    16.487827
# std        5.247202    46.342796              NaN     8.611614     8.611614
# min      -35.614895     0.253587              NaN     0.000000     3.000000
# 25%       -4.012720    29.925747              NaN     6.000000     9.000000
# 50%       -1.045194    44.173588              NaN    12.000000    15.000000
# 75%        2.192562    68.000710              NaN    21.000000    24.000000
# max       34.130856   914.816223              NaN    27.000000    30.000000
#
#         genre
# count    9981
# unique     10
# top     blues
# freq     1000
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN
#
# [11 rows x 61 columns]

# %% [markdown]
# ## Process single mp3 for validation

# %%
def process_single_mp3(mp3_file_path):
    wav_file_path = convert_mp3_to_wav(mp3_file_path)
    if wav_file_path:
        features_list = extract_features(wav_file_path)
        if features_list:
            df_new = pd.DataFrame(features_list)
            output_csv_filename = os.path.basename(mp3_file_path).replace('.mp3', '_features.csv')
            output_csv_path = os.path.join(os.path.dirname(mp3_file_path), '..', output_csv_filename)
            df_new.to_csv(output_csv_path, index=False)
            print(f"Features extracted and saved to {output_csv_path}")
        else:
            print("No features extracted.")
    else:
        print("Failed to convert MP3 to WAV.")

# %% [markdown]
# Usage of validation data generator.

# %%
# Example usage
mp3_file_path = '/Users/isaiah/Desktop/Career/Projects/music-genre-detector/inputs/file.mp3'
process_single_mp3(mp3_file_path)
# Out:
# Features extracted and saved to /Users/isaiah/Desktop/Career/Projects/music-genre-detector/inputs/../file_features.csv
